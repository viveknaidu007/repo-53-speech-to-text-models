# %%
#running the code for one time only for one word
#without latency


import os
import pyaudio
import vosk
import json

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\github ai\vosk models\vosk-model-en-in-0.5"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# function to recognize speech from audio
def recognize_audio(audio):
    rec.AcceptWaveform(audio)

    # get the recognized text
    result = json.loads(rec.FinalResult())
    result_text = result["text"]
    
    return result_text

# function to capture audio from microphone with a duration limit
def capture_audio(duration, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# Main function to continuously capture and recognize live audio
def main():
    duration = 3 # Duration in seconds
    audio_data = capture_audio(duration)

    # Recognize the captured audio
    text = recognize_audio(audio_data)
    print("Recognized:", text)

if __name__ == "__main__":
    main()

# %%
#running the code continue till user interpets
#with latency

import os
import time
import pyaudio
import vosk
import json

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\github ai\vosk models\vosk-model-en-in-0.5"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# Function to recognize speech from audio and calculate latency
def recognize_single_word(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # Get the recognized text
    result = json.loads(rec.FinalResult())
    text = result["text"] if result else ""

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency

    return text, latency

# Function to capture audio from microphone with a short duration
def capture_audio(duration=0.5, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# main function to capture, recognize, and display results (runs only once)
def main():
    duration = 3  # here duuration in seconds for single word
    audio_data = capture_audio(duration)

    text, latency = recognize_single_word(audio_data)

    if text:
        print(f"Recognized: {text} (Latency: {latency:.2f} seconds)")
    else:
        print("Did not understand audio.")

# Run the main function only once
if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognized: hello diseases is a can go to an art movie (Latency: 3.66 seconds)

# %%
#running continue loop of model
#with latency


import os
import pyaudio
import vosk
import json
import time

# set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\github ai\vosk models\vosk-model-en-in-0.5"

# initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# ffunction to recognize speech from audio
def recognize_audio(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # Get the recognized text
    result = json.loads(rec.FinalResult())
    result_text = result["text"]

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency
    
    return result_text, latency

# function to capture audio from microphone with a duration limit
def capture_audio(duration, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# main function to continuously capture and recognize live audio
def main():
    while True:
        duration = 10  # Duration in seconds
        audio_data = capture_audio(duration)

        # Recognize the captured audio
        text, latency = recognize_audio(audio_data)
        print(f"Recognized: {text} (Latency: {latency:.2f} seconds)")

if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognized: the multiplayer of her power that a tonne down omelette with anger domain (Latency: 2.37 seconds)
# Listening...
# Recognized:  (Latency: 0.66 seconds)
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 62
#      59         print(f"Recognized: {text} (Latency: {latency:.2f} seconds)")
#      61 if __name__ == "__main__":
# ---> 62     main()
#
# Cell In[11], line 55, in main()
#      53 while True:
#      54     duration = 10  # Duration in seconds
# ---> 55     audio_data = capture_audio(duration)
#      57     # Recognize the captured audio
#      58     text, latency = recognize_audio(audio_data)
#
# Cell In[11], line 42, in capture_audio(duration, rate, chunk)
#      40 frames = []
#      41 for i in range(0, int(rate / chunk * duration)):
# ---> 42     data = stream.read(chunk)
#      43     frames.append(data)
# ...

# %%
# !pip install googletrans

# %%
from googletrans import Translator
translator = Translator()
translated = translator.translate('hello' , dest='hi')

print(translated.text)  # This line is optional to print the translated text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 3
#       1 from googletrans import Translator
#       2 translator = Translator()
# ----> 3 translated = translator.translate('hello' , dest='hi')
#       5 print(translated.text)  # This line is optional to print the translated text
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\googletrans\client.py:182, in Translator.translate(self, text, dest, src, **kwargs)
#     179     return result
#     181 origin = text
# --> 182 data = self._translate(text, dest, src, kwargs)
#     184 # this code will be updated when the format is changed.
#     185 translated = ''.join([d[0] if d[0] else '' for d in data[0]])
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
# ...

# %%
import time
from googletrans import Translator

MAX_RETRIES = 3  # Maximum number of retries

translator = Translator()

for attempt in range(1, MAX_RETRIES + 1):
    try:
        translated = translator.translate('hello' , dest='hi')
        print(translated.text)
        break  # Translation successful, exit the loop
    except Exception as e:
        print(f"Translation failed (attempt {attempt}/{MAX_RETRIES}): {e}")
        time.sleep(2)  # Wait 2 seconds before retrying

if attempt == MAX_RETRIES:
    print("Translation failed after all retries.")
# Out:
# Translation failed (attempt 1/3): 'NoneType' object has no attribute 'group'
# Translation failed (attempt 2/3): 'NoneType' object has no attribute 'group'
# Translation failed (attempt 3/3): 'NoneType' object has no attribute 'group'
# Translation failed after all retries.

# %%
import os
import time
import pyaudio
import vosk
import json
from googletrans import Translator

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\github ai\vosk models\vosk-model-en-in-0.5"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# Function to recognize speech from audio and calculate latency
def recognize_single_word(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # Get the recognized text
    result = json.loads(rec.FinalResult())
    text = result["text"] if result else ""

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency

    return text, latency

# Function to capture audio from microphone with a short duration
def capture_audio(duration=0.5, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# Function to translate text
def translate_text(text, target_language='fr'):
    translator = Translator()
    translation = translator.translate(text, dest=target_language)
    return translation.text

# Main function to capture, recognize, translate, and display results (runs only once)
def main():
    duration = 2  # Duration in seconds (adjusted for single word)
    audio_data = capture_audio(duration)

    text, latency = recognize_single_word(audio_data)

    if text:
        translation = translate_text(text, target_language='fr')  # Change 'fr' to your target language code
        print(f"Recognized: {text} (Translated: {translation}) (Latency: {latency:.2f} seconds)")
    else:
        print("Did not understand audio.")

# Run the main function only once
if __name__ == "__main__":
    main()
# Out:
# Listening...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 69
#      67 # Run the main function only once
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# Cell In[28], line 62, in main()
#      59 text, latency = recognize_single_word(audio_data)
#      61 if text:
# ---> 62     translation = translate_text(text, target_language='fr')  # Change 'fr' to your target language code
#      63     print(f"Recognized: {text} (Translated: {translation}) (Latency: {latency:.2f} seconds)")
#      64 else:
#
# Cell In[28], line 51, in translate_text(text, target_language)
#      49 def translate_text(text, target_language='fr'):
#      50     translator = Translator()
# ---> 51     translation = translator.translate(text, dest=target_language)
#      52     return translation.text
#
# ...

# %%
import os
import pyaudio
import vosk
import json
import time
from googletrans import Translator

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\github ai\vosk models\vosk-model-en-in-0.5"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# Initialize the Google Translate API
translator = Translator()

# Function to recognize speech from audio
def recognize_audio(audio):
    start_time = time.time()

    rec.AcceptWaveform(audio)

    # Get the recognized text
    result = json.loads(rec.FinalResult())
    result_text = result["text"]

    end_time = time.time()
    latency = end_time - start_time
    
    return result_text, latency

# Function to capture audio from microphone with a duration limit
def capture_audio(duration, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# Main function to continuously capture and recognize live audio
def main():
    while True:
        duration = 2  # Duration in seconds
        audio_data = capture_audio(duration)

        # Recognize the captured audio
        recognized_text, latency = recognize_audio(audio_data)
        print(f"Recognized: {recognized_text} (Latency: {latency:.2f} seconds)")

        try:
            # Translate the recognized text
            translated_text = translator.translate(recognized_text, src="en", dest="hi").text
            print(f"Translated (English to Japanese): {translated_text}")
        except AttributeError:
            print("Translation failed. Skipping this result.")

if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognized: hello (Latency: 0.17 seconds)
# Translation failed. Skipping this result.
# Listening...
# Recognized: hello (Latency: 0.16 seconds)
# Translation failed. Skipping this result.
# Listening...
# Recognized:  (Latency: 0.19 seconds)
# Translation failed. Skipping this result.
# Listening...
# Recognized: and (Latency: 0.31 seconds)
# Translation failed. Skipping this result.
# Listening...
# Recognized:  (Latency: 0.16 seconds)
# Translation failed. Skipping this result.
# Listening...
# Recognized: hello (Latency: 0.34 seconds)
# Translation failed. Skipping this result.
# Listening...
# Recognized:  (Latency: 0.14 seconds)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 69
#      66             print("Translation failed. Skipping this result.")
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# ...

# %%
from googletrans import Translator
translator = Translator()
translator.detect('이 문장은 한글로 쓰여졌습니다.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 from googletrans import Translator
#       2 translator = Translator()
# ----> 3 translator.detect('이 문장은 한글로 쓰여졌습니다.')
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\googletrans\client.py:255, in Translator.detect(self, text, **kwargs)
#     252         result.append(lang)
#     253     return result
# --> 255 data = self._translate(text, 'en', 'auto', kwargs)
#     257 # actual source language that will be recognized by Google Translator when the
#     258 # src passed is equal to auto.
#     259 src = ''
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
#      77 def _translate(self, text, dest, src, override):
# ---> 78     token = self.token_acquirer.do(text)
# ...

# %%
from googletrans import Translator
translator = Translator()
translator.detect('hello')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 from googletrans import Translator
#       2 translator = Translator()
# ----> 3 translator.detect('hello')
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\googletrans\client.py:255, in Translator.detect(self, text, **kwargs)
#     252         result.append(lang)
#     253     return result
# --> 255 data = self._translate(text, 'en', 'auto', kwargs)
#     257 # actual source language that will be recognized by Google Translator when the
#     258 # src passed is equal to auto.
#     259 src = ''
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\googletrans\client.py:78, in Translator._translate(self, text, dest, src, override)
#      77 def _translate(self, text, dest, src, override):
# ---> 78     token = self.token_acquirer.do(text)
# ...

# %%
import os
import time
import random
import pyaudio
import vosk
import json

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\github ai\vosk models\vosk-model-en-in-0.5"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# Choose one of the following methods for reference text:

# Method 1: Load reference text from a file (recommended for large lists)
# with open("reference_text.txt", "r") as f:
#     reference_text = f.readlines()

# Method 2: Define reference text as a list within the code (for small sets)
reference_text = [
    "hello world",
    "how are you today",
    "this is a test"
]

# Function to recognize speech from audio and calculate latency
def recognize_single_word(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # Get the recognized text
    result = json.loads(rec.FinalResult())
    text = result["text"] if result else ""

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency

    return text, latency

# Function to capture audio from microphone with a short duration
def capture_audio(duration=0.5, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# Main function to capture, recognize, and display results continuously
def main():
    correct_words = 0
    total_words = 0

    while True:
        # Choose a random sentence from the reference text
        current_sentence = random.choice(reference_text).strip()

        # Print the sentence for the user to read
        print(f"Please say: {current_sentence}")

        duration = 2  # Duration in seconds (adjusted for single word)
        audio_data = capture_audio(duration)

        text, latency = recognize_single_word(audio_data)

        if text:
            print(f"Recognized: {text} (Latency: {latency:.2f} seconds)")
            correct_words += 1 if text == current_sentence else 0  # Check for exact match
        else:
            print("Did not understand audio.")

        total_words += len(current_sentence.split())  # Count words in the sentence

        # Calculate and display word-level accuracy
        accuracy = (correct_words / total_words) * 100
