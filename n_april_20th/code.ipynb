# %%
# !pip install googletrans
#above was not working

# %%
pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: httpx==0.13.3 in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from googletrans==3.1.0a0) (0.13.3)
# Requirement already satisfied: certifi in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.2.2)
# Requirement already satisfied: hstspreload in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.4.1)
# Requirement already satisfied: sniffio in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Requirement already satisfied: chardet==3.* in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpx==0.13.3->googletrans==3.1.0a0) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\poppo\anaconda3\envs\vosk\lib\site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0) (3.0.0)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py): started
#   Building wheel for googletrans (setup.py): finished with status 'done'
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16414 sha256=3340cfac5dae6dce43a00cd2e303855bfddd13b70af6c22a7b48f56345c1668b
#   Stored in directory: c:\users\poppo\appdata\local\pip\cache\wheels\96\ac\bd\9df9eab356c0576896e97147425987f6f45e9e46456c978d18
# Successfully built googletrans
# Installing collected packages: googletrans
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# Successfully installed googletrans-3.1.0a0
# Note: you may need to restart the kernel to use updated packages.

# %%
from googletrans import Translator

def translate_text(text, target_language='en'):
    translator = Translator()
    translated_text = translator.translate(text, dest=target_language)
    return translated_text.text

# xample usage:
text_to_translate = "how are you"
translated_text = translate_text(text_to_translate, target_language='hi')
print("Translated Text:", translated_text)
# Out:
# Translated Text: आप कैसे हैं

# %%
#for english

#running continue loop of model
#with latency


import os
import pyaudio
import vosk
import json
import time

# set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\downloads firefox\vosk models\vosk-model-small-en-in-0.4"

# initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# ffunction to recognize speech from audio
def recognize_audio(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # getting the recognized text
    result = json.loads(rec.FinalResult())
    result_text = result["text"]

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency
    
    return result_text, latency

# function to capture audio from microphone with a duration limit
def capture_audio(duration, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# main function to continuously capture and recognize live audio
def main():
    while True:
        duration = 10  # duration in seconds
        audio_data = capture_audio(duration)

        # recognize the captured audio
        text, latency = recognize_audio(audio_data)
        print(f"Recognized: {text} (Latency: {latency:.2f} seconds)")

if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognized: i'm not speaking and restricting it was taking them die (Latency: 1.33 seconds)
# Listening...
# Recognized: it was taping let's take this (Latency: 0.84 seconds)
# Listening...
# Recognized:  (Latency: 0.40 seconds)
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      61         print(f"Recognized: {text} (Latency: {latency:.2f} seconds)")
#      63 if __name__ == "__main__":
# ---> 64     main()
#
# Cell In[1], line 57, in main()
#      55 while True:
#      56     duration = 10  # duration in seconds
# ---> 57     audio_data = capture_audio(duration)
#      59     # recognize the captured audio
#      60     text, latency = recognize_audio(audio_data)
#
# Cell In[1], line 44, in capture_audio(duration, rate, chunk)
#      42 frames = []
#      43 for i in range(0, int(rate / chunk * duration)):
# ---> 44     data = stream.read(chunk)
#      45     frames.append(data)
#      47 stream.stop_stream()
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
#for using google transcriber
#with latency


import os
import pyaudio
import vosk
import json
import time
from googletrans import Translator

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\downloads firefox\vosk models\vosk-model-small-en-in-0.4"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# initialize Google Translator
translator = Translator()

# function to recognize speech from audio
def recognize_audio(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # getting the recognized text
    result = json.loads(rec.FinalResult())
    result_text = result["text"]

    # translate the recognized text to English
    translated_text = translator.translate(result_text, dest='hi').text

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency
    
    return translated_text, latency

# function to capture audio from microphone with a duration limit
def capture_audio(duration, rate=20000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)

    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# main function to continuously capture and recognize live audio
def main():
    while True:
        duration = 10  # Duration in seconds
        audio_data = capture_audio(duration)

        # recognize the captured audio
        text, latency = recognize_audio(audio_data)
        print(f"Recognized (Translated): {text} (Latency: {latency:.2f} seconds)")

if __name__ == "__main__":
    main()
# Out:
# Listening...
# Recognized (Translated): नमस्ते यह है नमस्ते यह है (Latency: 1.55 seconds)
# Listening...
# Recognized (Translated): ओह, वास्तव में चीजें पढ़ना खेलना पसंद है (Latency: 1.90 seconds)
# Listening...
# Recognized (Translated): से आते हैं (Latency: 1.64 seconds)
# Listening...
# Recognized (Translated): यही वह जगह है जहां लोगों ने हत्या की या यह ठीक था (Latency: 1.21 seconds)
# Listening...
# Recognized (Translated): हम अपने पानी के लिए विलंबता को एक अक्षर तक बढ़ाते हैं (Latency: 1.68 seconds)
# Listening...
# Recognized (Translated): ऐसा नहीं था कि उन्हें गानों का प्रशिक्षण नहीं दिया गया है (Latency: 1.64 seconds)
# Listening...
# Recognized (Translated): ओह (Latency: 0.94 seconds)
# Listening...
# Recognized (Translated): मेरे दिन की तुलना में अच्छा है (Latency: 2.05 seconds)
# Listening...
# Recognized (Translated): ओह के ऐसे बैंड के लिए हम कम से कम बोल रहे होंगे हम रिपोर्ट बोल रहे होंगे और एक और ठीक पर झुकेंगे (Latency: 1.56 seconds)
# Listening...
# Recognized (Translated): पिछले पूरे सप्ताह (Latency: 2.11 seconds)
# Listening...
# Recognized (Translated): एक भी शब्द नहीं है (Latency: 1.32 seconds)
# Listening...
# Recognized (Translated): जो कम से कम सज़ा सुनाएगा (Latency: 1.65 seconds)
# Listening...
# Recognized (Translated): क्योंकि मैं अकेला नहीं रहूंगा (Latency: 1.21 seconds)
# Listening...
# Recognized (Translated): ओह, कृपया (Latency: 1.27 seconds)
# Listening...
# Recognized (Translated): दस (Latency: 0.58 seconds)
# Listening...
# Recognized (Translated): प्रश्न ताकि हम जारी रख सकें (Latency: 1.35 seconds)
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 69
#      66         print(f"Recognized (Translated): {text} (Latency: {latency:.2f} seconds)")
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# Cell In[3], line 62, in main()
#      60 while True:
#      61     duration = 10  # Duration in seconds
# ---> 62     audio_data = capture_audio(duration)
#      64     # recognize the captured audio
#      65     text, latency = recognize_audio(audio_data)
#
# Cell In[3], line 49, in capture_audio(duration, rate, chunk)
#      47 frames = []
#      48 for i in range(0, int(rate / chunk * duration)):
# ---> 49     data = stream.read(chunk)
#      50     frames.append(data)
#      52 stream.stop_stream()
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:

# %%
#giving some wrong outputs for experiment
'''

import os
import pyaudio
import vosk
import json
import time
from googletrans import Translator
import keyboard

# Set the path to the Vosk model
MODEL_PATH = r"C:\Users\poppo\Desktop\downloads firefox\vosk models\vosk-model-small-en-in-0.4"

# Initialize the Vosk model
vosk.SetLogLevel(-1)
model = vosk.Model(MODEL_PATH)
rec = vosk.KaldiRecognizer(model, 16000)

# Initialize Google Translator
translator = Translator()

# Function to recognize speech from audio
def recognize_audio(audio):
    start_time = time.time()  # Record start time

    rec.AcceptWaveform(audio)

    # Get the recognized text
    result = json.loads(rec.FinalResult())
    result_text = result["text"]

    # Translate the recognized text to English
    translated_text = translator.translate(result_text, dest='en').text

    end_time = time.time()  # Record end time
    latency = end_time - start_time  # Calculate latency
    
    return translated_text, latency

# Function to capture audio from microphone with a duration limit
def capture_audio(duration, rate=16000, chunk=1024):
    audio = pyaudio.PyAudio()
    stream = audio.open(format=pyaudio.paInt16, channels=1, rate=rate, input=True, frames_per_buffer=chunk)
    print("Listening...")

    frames = []
    for i in range(0, int(rate / chunk * duration)):
        data = stream.read(chunk)
        frames.append(data)
        if keyboard.is_pressed('e'):  # Check if 'e' key is pressed
            break
    
    stream.stop_stream()
    stream.close()
    audio.terminate()

    return b"".join(frames)

# Main function to continuously capture and recognize live audio
def main():
    while True:
        duration = 3  # Duration in seconds
        audio_data = capture_audio(duration)

        # Recognize the captured audio
        text, latency = recognize_audio(audio_data)
        print(f"Recognized (Translated): {text} (Latency: {latency:.2f} seconds)")

        if keyboard.is_pressed('e'):  # Check if 'e' key is pressed
            print("Stopping...")
            break

if __name__ == "__main__":
    main()
'''
# Out:
# Listening...
# Recognized (Translated): jagger (Latency: 0.52 seconds)
# Listening...
# Recognized (Translated): driver (Latency: 0.58 seconds)
# Listening...
# Recognized (Translated):  (Latency: 0.37 seconds)
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 72
#      69             break
#      71 if __name__ == "__main__":
# ---> 72     main()
#
# Cell In[3], line 61, in main()
#      59 while True:
#      60     duration = 3  # Duration in seconds
# ---> 61     audio_data = capture_audio(duration)
#      63     # Recognize the captured audio
#      64     text, latency = recognize_audio(audio_data)
#
# Cell In[3], line 46, in capture_audio(duration, rate, chunk)
#      44 frames = []
#      45 for i in range(0, int(rate / chunk * duration)):
# ---> 46     data = stream.read(chunk)
#      47     frames.append(data)
#      48     if keyboard.is_pressed('e'):  # Check if 'e' key is pressed
#
# File c:\Users\poppo\anaconda3\envs\vosk\Lib\site-packages\pyaudio\__init__.py:570, in PyAudio.Stream.read(self, num_frames, exception_on_overflow)
#     567 if not self._is_input:
#     568     raise IOError("Not input stream",
#     569                   paCanNotReadFromAnOutputOnlyStream)
# --> 570 return pa.read_stream(self._stream, num_frames,
#     571                       exception_on_overflow)
#
# KeyboardInterrupt:
